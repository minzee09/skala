# %% [markdown]
# #### 다음 실습 코드는 학습 목적으로만 사용 바랍니다. 문의 : audit@korea.ac.kr 임성열 Ph.D.

# %%
# python -m venv prompt
# pip install -r requirements-prompt.txt
# 이미 설치했다면 아래 셀은 실행하지 않습니다.
# ------------------------------------------------------------

# pip install langchain-core langchain-community langchain-openai langchain-text-splitters faiss-cpu pypdf python-dotenv ipywidgets

# %% [markdown]
# python -m venv prompt ⇒ prompt라는 가상 환경 생성
#
# source ./prompt/bin/activate
#
# pip install -r 파일위치/requirements-prompt.txt

# %% [markdown]
# <b> 논문: "Attention Is All You Need"
#
# 프롬프트 주제:
# <li> 프롬프트1. Transformer가 딥러닝과 다르게 생성형 모델로 작동하는 이유
# <li> 프롬프트2. Transformer가 멀티모달 인간 모방 트렌드를 위한 것이라는 논리
# <li> 프롬프트3. 딥러닝 vs Transformer – 뇌 vs 언어습득 방식 모방
# <li> 각 프롬프트는 Chain of Thought (CoT) → Self-Consistency (SC) → ReAct 흐름에 맞게 구성 <b>

# %% [markdown]
# <b>📘 프롬프트 1 (CoT → SC → ReAct)
# <li> Transformer 모델은 여전히 딥러닝 프레임워크에서 학습되지만, 그 구조는 순환이나 컨볼루션 없이 동작하며 실제로는 생성형 모델처럼 기능합니다.
# <li> 이러한 구조적 특성이 왜 딥러닝의 연산 방식과 다른 방향으로 작동하게 되는지 단계별로 설명해 보세요. ← 🧠 CoT
# <li> 그런 다음, 이 구조가 다른 딥러닝 모델들과 비교해 생성적 추론 능력에서 어떤 정합성을 갖는지 평가해보세요. ← 🔍 SC
# <li> 마지막으로, Transformer의 구조를 다른 생성형 아키텍처(예: GAN, VAE)와 융합한다면 어떤 결과가 나올지 시뮬레이션 해보세요. ← 🛠 ReAct <b>

# %% [markdown]
# <b>📘 프롬프트 2 (CoT → SC → ReAct)
# <li> Transformer 구조는 언어, 이미지, 코드 등 다양한 모달리티에 동일하게 적용되는 특성이 있습니다.
# <li> 왜 이런 구조가 인간의 멀티모달 처리 방식을 모방했다고 볼 수 있는지 단계적으로 추론해 보세요. ← 🧠 CoT
# <li> 이어서, CNN, RNN 등 기존 아키텍처와 비교하여 Transformer가 멀티모달 통합에 있어 더 정합적인 이유를 평가해보세요. ← 🔍 SC
# <li> 마지막으로, Transformer가 실제 인간의 감각 처리 흐름(예: 시각 + 언어 통합)을 모방하는 가상의 시나리오를 구성해보세요. ← 🛠 ReAct </b>

# %% [markdown]
# <b> 📘 프롬프트 3 (CoT → SC → ReAct)
# <li> 딥러닝은 주로 뇌의 신경망 구조를 흉내내는 데서 시작되었지만, Transformer는 인간의 언어 습득 과정을 모방한 것이라는 주장이 있습니다.
# <li> 이 두 가지 철학적 차이를 구체적으로 비교 분석하며 단계적으로 설명해 보세요. ← 🧠 CoT
# <li> 실제 학습 방식이나 데이터 사용 관점에서 이 차이가 어떤 정합성을 갖는지도 논리적으로 검토해보세요. ← 🔍 SC
# <li> 마지막으로, Transformer가 아이가 언어를 익히는 방식과 유사하게 학습되는 사례를 시뮬레이션해 보세요. ← 🛠 ReAct </b>

# %%
# python -m venv llm
# pip install -r requirements-llm.txt
# 이미 설치했다면 아래 셀은 실행하지 않습니다.
# ------------------------------------------------------------

# %pip install langchain-core langchain-community langchain-openai faiss-cpu pypdf

# %%
#논문 로딩
from pypdf import PdfReader

def load_paper(path):
    reader = PdfReader(path)
    return "\n".join([p.extract_text() for p in reader.pages if p.extract_text()])

paper_text = load_paper("paper-attention.pdf")

# %%
# Step 3. 문서 분할(Text Splitting) 및 FAISS 벡터 데이터베이스 생성

# 불필요한 경고 문구를 출력하지 않음
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import os

from dotenv import load_dotenv

from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

# .env 파일에서 환경변수 불러오기
load_dotenv()

# OpenAI API Key 읽기
openai_api_key = os.getenv("OPENAI_API_KEY")

if not openai_api_key:
    raise ValueError(
        "OPENAI_API_KEY가 설정되어 있지 않습니다.\n"
        ".env 파일에 OPENAI_API_KEY를 추가하세요."
    )

# Text Splitter 생성
#
# chunk_size
#   하나의 Chunk가 가질 최대 문자 수
#
# chunk_overlap
#   이전 Chunk와 공유할 문자 수
#
# Overlap을 주면 문맥(Context)이 끊어지는 현상을 줄일 수 있다.
#
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
)

# 논문 문서를 여러 개의 Chunk로 분할
#
# paper_text :
# 이전 단계에서 PDF로부터 추출한 논문 원문
#
docs = text_splitter.create_documents([paper_text])

print(f"생성된 문단 수 : {len(docs)}")

# OpenAI Embedding 모델 생성
#
# 기본 모델 :
# text-embedding-3-small
#
embedding_model = OpenAIEmbeddings(
    api_key=openai_api_key,
    model="text-embedding-3-small",
)

# 문서를 임베딩하여
# FAISS Vector Database 생성
vectorstore = FAISS.from_documents(
    docs,
    embedding_model,
)

print("✅ FAISS Vector DB 생성 완료")
print(f"저장된 문서 수 : {vectorstore.index.ntotal}")
# Out:
# 생성된 문단 수 : 89
# ✅ FAISS Vector DB 생성 완료
# 저장된 문서 수 : 89

# %%
#프롬프트 목록(한글)
prompts = [
    """Transformer 모델은 여전히 딥러닝 프레임워크에서 학습되지만, 그 구조는 순환이나 컨볼루션 없이 동작하며 실제로는 생성형 모델처럼 기능합니다.
이러한 구조적 특성이 왜 딥러닝의 연산 방식과 다른 방향으로 작동하게 되는지 단계별로 설명해 보세요.
그런 다음, 이 구조가 다른 딥러닝 모델들과 비교해 생성적 추론 능력에서 어떤 정합성을 갖는지 평가해보세요.
마지막으로, Transformer의 구조를 다른 생성형 아키텍처(예: GAN, VAE)와 융합한다면 어떤 결과가 나올지 시뮬레이션 해보세요.""",

    """Transformer 구조는 언어, 이미지, 코드 등 다양한 모달리티에 동일하게 적용되는 특성이 있습니다.
왜 이런 구조가 인간의 멀티모달 처리 방식을 모방했다고 볼 수 있는지 단계적으로 추론해 보세요.
이어서, CNN, RNN 등 기존 아키텍처와 비교하여 Transformer가 멀티모달 통합에 있어 더 정합적인 이유를 평가해보세요.
마지막으로, Transformer가 실제 인간의 감각 처리 흐름(예: 시각 + 언어 통합)을 모방하는 가상의 시나리오를 구성해보세요.""",

    """딥러닝은 주로 뇌의 신경망 구조를 흉내내는 데서 시작되었지만, Transformer는 인간의 언어 습득 과정을 모방한 것이라는 주장이 있습니다.
이 두 가지 철학적 차이를 구체적으로 비교 분석하며 단계적으로 설명해 보세요.
실제 학습 방식이나 데이터 사용 관점에서 이 차이가 어떤 정합성을 갖는지도 논리적으로 검토해보세요.
마지막으로, Transformer가 아이가 언어를 익히는 방식과 유사하게 학습되는 사례를 시뮬레이션해 보세요."""
]

# %%
#LLM으로 답변 생성 함수
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

def answer_with_context(prompt, top_k=3):
    related_docs = vectorstore.similarity_search(prompt, k=top_k)
    context = "\n\n".join([doc.page_content for doc in related_docs])
    full_prompt = f"""너는 논문 기반 연구 보조 AI야.
다음은 논문에서 발췌한 내용이야:\n\n{context}\n\n이제 아래 복합 질문에 단계적으로 답변해줘:\n{prompt}"""
    
    llm = ChatOpenAI(model="gpt-4o", temperature=0.3)
    return llm.invoke([HumanMessage(content=full_prompt)]).content

# %%
#실행 및 결과 출력
for i, q in enumerate(prompts, 1):
    print(f"\n🧠 복합 프롬프트 {i}:\n{q}\n")
    response = answer_with_context(q)
    print(f"💬 GPT-4o 응답 {i}:\n{response}\n{'-'*80}")
# Out:
# 🧠 복합 프롬프트 1:
# Transformer 모델은 여전히 딥러닝 프레임워크에서 학습되지만, 그 구조는 순환이나 컨볼루션 없이 동작하며 실제로는 생성형 모델처럼 기능합니다.
# 이러한 구조적 특성이 왜 딥러닝의 연산 방식과 다른 방향으로 작동하게 되는지 단계별로 설명해 보세요.
# 그런 다음, 이 구조가 다른 딥러닝 모델들과 비교해 생성적 추론 능력에서 어떤 정합성을 갖는지 평가해보세요.
# 마지막으로, Transformer의 구조를 다른 생성형 아키텍처(예: GAN, VAE)와 융합한다면 어떤 결과가 나올지 시뮬레이션 해보세요.
#
# 💬 GPT-4o 응답 1:
# Transformer 모델은 순환 신경망(RNN)이나 합성곱 신경망(CNN)을 사용하지 않고도 효과적으로 작동하는 독특한 구조를 가지고 있습니다. 이 구조적 특성이 딥러닝의 전통적인 연산 방식과 어떻게 다른 방향으로 작동하는지 단계별로 설명하겠습니다.
#
# ### 1. Transformer의 구조적 특성
#
# - **Self-Attention Mechanism**: Transformer는 self-attention 메커니즘을 사용하여 입력 시퀀스의 각 요소가 다른 모든 요소와의 관계를 고려할 수 있게 합니다. 이는 RNN처럼 순차적으로 정보를 처리하지 않고, 병렬적으로 모든 위치의 정보를 동시에 처리할 수 있게 합니다.
#
# - **병렬 처리**: RNN은 순차적으로 데이터를 처리하기 때문에 긴 시퀀스를 처리하는 데 시간이 많이 걸릴 수 있습니다. 반면, Transformer는 self-attention을 통해 모든 위치의 정보를 동시에 처리할 수 있어 병렬 처리가 가능하며, 이는 학습 속도를 크게 향상시킵니다.
#
# - **Position-wise Feed-Forward Networks**: 각 self-attention 레이어 뒤에는 위치별 피드포워드 네트워크가 있어, 각 위치의 정보를 독립적으로 처리합니다. 이는 각 위치의 정보를 더욱 풍부하게 만들어 줍니다.
#
# ### 2. 생성적 추론 능력에서의 정합성 평가
#
# Transformer의 이러한 구조는 생성적 추론 능력에서 몇 가지 장점을 제공합니다.
#
# - **장기 의존성 처리**: self-attention 메커니즘은 입력 시퀀스 내의 모든 요소 간의 관계를 고려하기 때문에, 장기 의존성을 효과적으로 처리할 수 있습니다. 이는 RNN이 가지는 기울기 소실 문제를 피할 수 있게 합니다.
#
# - **유연한 구조**: Transformer는 입력 시퀀스의 길이에 구애받지 않고 작동할 수 있어, 다양한 길이의 시퀀스를 효과적으로 처리할 수 있습니다.
#
# - **생성적 모델로서의 효율성**: Transformer는 이전에 생성된 출력을 입력으로 사용하여 다음 출력을 생성할 수 있어, 자연어 생성(NLG) 작업에서 매우 효과적입니다.
#
# ### 3. Transformer와 다른 생성형 아키텍처의 융합 시뮬레이션
#
# Transformer를 다른 생성형 아키텍처와 융합하면 흥미로운 결과를 얻을 수 있습니다.
#
# - **Transformer + GAN**: GAN의 생성자와 판별자 구조에 Transformer를 도입하면, 고해상도 이미지 생성에서 더 복잡한 패턴을 학습할 수 있을 것입니다. Transformer의 self-attention은 이미지의 다양한 부분 간의 관계를 잘 포착할 수 있어, 더 정교한 이미지 생성이 가능할 것입니다.
#
# - **Transformer + VAE**: VAE의 인코더-디코더 구조에 Transformer를 사용하면, 잠재 공간에서의 복잡한 패턴을 더 잘 학습할 수 있을 것입니다. 이는 더 다양한 데이터 분포를 모델링하는 데 유리할 수 있습니다.
#
# 이러한 융합은 각각의 모델이 가진 장점을 결합하여, 더 강력하고 유연한 생성형 모델을 개발하는 데 기여할 수 있을 것입니다.
# --------------------------------------------------------------------------------
#
# 🧠 복합 프롬프트 2:
# Transformer 구조는 언어, 이미지, 코드 등 다양한 모달리티에 동일하게 적용되는 특성이 있습니다.
# 왜 이런 구조가 인간의 멀티모달 처리 방식을 모방했다고 볼 수 있는지 단계적으로 추론해 보세요.
# 이어서, CNN, RNN 등 기존 아키텍처와 비교하여 Transformer가 멀티모달 통합에 있어 더 정합적인 이유를 평가해보세요.
# 마지막으로, Transformer가 실제 인간의 감각 처리 흐름(예: 시각 + 언어 통합)을 모방하는 가상의 시나리오를 구성해보세요.
#
# 💬 GPT-4o 응답 2:
# Transformer 구조가 인간의 멀티모달 처리 방식을 모방했다고 볼 수 있는 이유를 단계적으로 추론해 보겠습니다.
#
# 1. **자유로운 의존성 모델링**: Transformer는 self-attention 메커니즘을 통해 입력과 출력 간의 전역적인 의존성을 모델링합니다. 이는 인간이 정보를 처리할 때, 특정 정보 간의 물리적 거리나 순서에 구애받지 않고 관련성을 파악하는 방식과 유사합니다. 예를 들어, 우리는 문장을 읽을 때 단어 간의 물리적 거리에 상관없이 의미를 이해할 수 있습니다.
#
# 2. **병렬 처리 능력**: Transformer는 RNN과 달리 순차적인 처리 없이 병렬 처리가 가능합니다. 이는 인간이 여러 감각 정보를 동시에 처리할 수 있는 능력과 유사합니다. 우리는 시각, 청각 등의 정보를 동시에 받아들이고 통합하여 이해할 수 있습니다.
#
# 3. **모듈화된 정보 처리**: Transformer의 self-attention은 입력 데이터의 각 부분을 독립적으로 처리하면서도 전체적인 맥락을 고려합니다. 이는 인간이 특정 감각 정보를 개별적으로 분석하면서도 전체적인 상황을 이해하는 방식과 유사합니다.
#
# 이제 CNN, RNN 등 기존 아키텍처와 비교하여 Transformer가 멀티모달 통합에 있어 더 정합적인 이유를 평가해보겠습니다.
#
# 1. **CNN과의 비교**: CNN은 주로 지역적 패턴을 학습하는 데 강점을 가지며, 이미지 처리에 적합합니다. 그러나 전역적인 의존성 모델링에는 한계가 있습니다. 반면, Transformer는 self-attention을 통해 전역적인 의존성을 효과적으로 모델링할 수 있어, 다양한 모달리티의 통합에 유리합니다.
#
# 2. **RNN과의 비교**: RNN은 순차적인 데이터 처리에 적합하지만, 긴 시퀀스의 의존성을 학습하는 데 어려움이 있습니다. 또한, 순차적인 처리로 인해 병렬화가 어렵습니다. Transformer는 이러한 문제를 해결하며, 다양한 모달리티의 데이터를 동시에 처리할 수 있는 능력을 제공합니다.
#
# 마지막으로, Transformer가 실제 인간의 감각 처리 흐름을 모방하는 가상의 시나리오를 구성해보겠습니다.
#
# **시나리오: 시각과 언어의 통합**
#
# 한 사람이 자연 풍경을 보면서 친구와 대화를 나누고 있습니다. 이때, 그의 뇌는 시각 정보를 통해 나무, 하늘, 강 등의 이미지를 처리하고, 동시에 친구의 목소리를 통해 언어 정보를 처리합니다. Transformer 모델은 이와 유사하게, 시각 정보와 언어 정보를 각각의 self-attention 메커니즘을 통해 병렬적으로 처리하면서도, 두 정보 간의 연관성을 통합하여 전체적인 맥락을 이해합니다. 예를 들어, 친구가 "저 나무는 정말 크다"라고 말할 때, Transformer는 시각적 정보에서 '나무'를 찾아내고, 언어 정보와 결합하여 그 의미를 파악합니다. 이는 인간이 여러 감각을 통합하여 상황을 이해하는 방식과 유사합니다.
# --------------------------------------------------------------------------------
#
# 🧠 복합 프롬프트 3:
# 딥러닝은 주로 뇌의 신경망 구조를 흉내내는 데서 시작되었지만, Transformer는 인간의 언어 습득 과정을 모방한 것이라는 주장이 있습니다.
# 이 두 가지 철학적 차이를 구체적으로 비교 분석하며 단계적으로 설명해 보세요.
# 실제 학습 방식이나 데이터 사용 관점에서 이 차이가 어떤 정합성을 갖는지도 논리적으로 검토해보세요.
# 마지막으로, Transformer가 아이가 언어를 익히는 방식과 유사하게 학습되는 사례를 시뮬레이션해 보세요.
#
# 💬 GPT-4o 응답 3:
# 딥러닝의 초기 발전은 주로 인간 뇌의 신경망 구조를 모방하는 데 중점을 두었습니다. 이러한 접근 방식은 인공 신경망(Artificial Neural Networks, ANN)의 발전으로 이어졌으며, 이는 뇌의 뉴런과 시냅스의 상호작용을 수학적으로 모델링하여 컴퓨터가 학습할 수 있도록 하는 것이 목표였습니다. 이 접근 방식은 주로 순차적인 데이터 처리에 의존하며, 이는 인간의 뇌가 정보를 처리하는 방식과 유사하다고 여겨졌습니다.
#
# 반면, Transformer 모델은 인간의 언어 습득 과정을 모방하려는 시도로 볼 수 있습니다. Transformer는 주로 언어 모델링과 번역 작업에서 사용되며, 이는 인간이 언어를 배우는 방식과 유사한 점이 있습니다. Transformer의 핵심은 '자기 주의 메커니즘(self-attention mechanism)'으로, 이는 입력 데이터의 모든 부분이 서로 어떻게 관련되어 있는지를 동시에 고려할 수 있게 해줍니다. 이는 인간이 언어를 배울 때 문맥을 이해하고 단어 간의 관계를 파악하는 방식과 유사합니다.
#
# ### 단계적 비교 분석
#
# 1. **순차 처리 vs. 병렬 처리**:
#    - **신경망 기반 모델**: 전통적인 RNN(Recurrent Neural Networks)이나 LSTM(Long Short-Term Memory) 같은 모델은 순차적으로 데이터를 처리합니다. 이는 시계열 데이터나 자연어 처리에서 유용하지만, 긴 문장이나 복잡한 문맥을 처리할 때는 비효율적일 수 있습니다.
#    - **Transformer**: Transformer는 병렬 처리가 가능하여, 문장의 모든 단어를 동시에 처리할 수 있습니다. 이는 인간이 문장을 읽고 전체적인 의미를 빠르게 파악하는 방식과 유사합니다.
#
# 2. **의존성 처리**:
#    - **신경망 기반 모델**: RNN은 이전 상태를 기반으로 다음 상태를 예측하기 때문에, 긴 의존성을 처리하는 데 어려움이 있습니다.
#    - **Transformer**: 자기 주의 메커니즘을 통해, Transformer는 입력의 모든 부분이 서로 어떻게 관련되어 있는지를 동시에 고려할 수 있습니다. 이는 인간이 문맥을 이해하고 단어 간의 관계를 파악하는 방식과 유사합니다.
#
# 3. **학습 방식**:
#    - **신경망 기반 모델**: 주로 많은 양의 레이블된 데이터를 필요로 하며, 데이터의 순차적 특성을 이용합니다.
#    - **Transformer**: 사전 훈련(pre-training)과 미세 조정(fine-tuning)을 통해, 비교적 적은 양의 레이블된 데이터로도 높은 성능을 발휘할 수 있습니다. 이는 인간이 언어를 배우는 과정에서, 다양한 문맥을 통해 언어의 규칙을 학습하는 방식과 유사합니다.
#
# ### 정합성 검토
#
# Transformer의 학습 방식은 인간의 언어 습득 과정과 여러 면에서 유사성을 보입니다. 인간은 언어를 배우면서 단어 간의 관계와 문맥을 이해하고, 이를 통해 새로운 문장을 만들어냅니다. Transformer는 자기 주의 메커니즘을 통해 이러한 관계를 학습하며, 이는 데이터의 순차적 특성에 의존하지 않고도 문맥을 이해할 수 있게 합니다. 또한, 사전 훈련과 미세 조정은 인간이 언어를 배우는 과정에서의 '기초 학습'과 '심화 학습'에 비유될 수 있습니다.
#
# ### 시뮬레이션 사례
#
# Transformer가 아이가 언어를 익히는 방식과 유사하게 학습되는 사례를 시뮬레이션해보겠습니다.
#
# 1. **기초 학습 단계 (Pre-training)**:
#    - 아이가 다양한 소리와 단어를 듣고, 이를 통해 언어의 기본적인 규칙을 학습하는 단계입니다.
#    - Transformer는 대량의 텍스트 데이터를 통해 언어의 기본적인 구조와 패턴을 학습합니다.
#
# 2. **심화 학습 단계 (Fine-tuning)**:
#    - 아이가 특정한 상황에서 사용되는 문장이나 표현을 배우는 단계입니다.
#    - Transformer는 특정한 작업(예: 번역, 요약 등)에 맞춰 미세 조정됩니다.
#
# 3. **응용 및 생성**:
#    - 아이가 배운 언어를 사용하여 새로운 문장을 만들고, 다양한 상황에서 의사소통을 합니다.
#    - Transformer는 학습된 내용을 바탕으로 새로운 텍스트를 생성하거나, 주어진 문장을 번역합니다.
#
# 이러한 시뮬레이션은 Transformer가 인간의 언어 학습 과정을 모방하여, 효율적이고 유연하게 언어를 처리할 수 있음을 보여줍니다.
# --------------------------------------------------------------------------------
